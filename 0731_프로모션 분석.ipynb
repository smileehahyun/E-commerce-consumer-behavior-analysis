# %%
import pymysql
conn = pymysql.connect(
    host='127.0.0.1',
    user='root',
    password='sqlstudy',
    db='ecommerce_db',
    charset='utf8'
)

from sqlalchemy import create_engine
import pandas as pd

# 1. SQLAlchemy 엔진 생성
engine = create_engine("mysql+pymysql://root:sqlstudy@127.0.0.1/ecommerce_db")

# %%
query = """
SELECT COUNT(DISTINCT(session_id))
FROM view_click_stream_add_to_cart
"""
df_add_to_cart = pd.read_sql(query, engine)

# %%
df_add_to_cart
# Out:
#    COUNT(DISTINCT(session_id))
# 0                       872061

# %%
query = """
SELECT COUNT(DISTINCT(session_id))
FROM transactions
"""
df_transactions = pd.read_sql(query, engine)

# %%
df_transactions
# Out:
#    COUNT(DISTINCT(session_id))
# 0                       852584

# %%
df= pd.read_csv('/Users/hapresent/Desktop/데이터톤/데이터 분석/product_price_label.csv')

# %%
df
# Out:
#        product_id  item_price   price_label
# 0           31439      269109  middle price
# 1           47995      521009    high price
# 2           46001      251023  middle price
# 3            5727      505707    high price
# 4           50243      196051  middle price
# ...           ...         ...           ...
# 44441       24344      265327  middle price
# 44442       33206      292791  middle price
# 44443        2309      181788  middle price
# 44444       54390      256459  middle price
# 44445       19330      198181  middle price
#
# [44446 rows x 3 columns]

# %%
query = """
SELECT *
FROM product
"""
df_product = pd.read_sql(query, engine)

# %%
df_product
# Out:
#        product_id gender masterCategory subCategory            articleType  \
# 0           15970    Men        Apparel     Topwear                 Shirts
# 1           39386    Men        Apparel  Bottomwear                  Jeans
# 2           59263  Women    Accessories     Watches                Watches
# 3           21379    Men        Apparel  Bottomwear            Track Pants
# 4           53759    Men        Apparel     Topwear                Tshirts
# ...           ...    ...            ...         ...                    ...
# 44441       17036    Men       Footwear       Shoes           Casual Shoes
# 44442        6461    Men       Footwear  Flip Flops             Flip Flops
# 44443       18842    Men        Apparel     Topwear                Tshirts
# 44444       46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445       51623  Women    Accessories     Watches                Watches
#
#       baseColour  season  year   usage  \
# ...

# %%
df_merged = pd.merge(df_product, df, on='product_id', how='left')

# %%
df_merged
# Out:
#        product_id gender masterCategory subCategory            articleType  \
# 0           15970    Men        Apparel     Topwear                 Shirts
# 1           39386    Men        Apparel  Bottomwear                  Jeans
# 2           59263  Women    Accessories     Watches                Watches
# 3           21379    Men        Apparel  Bottomwear            Track Pants
# 4           53759    Men        Apparel     Topwear                Tshirts
# ...           ...    ...            ...         ...                    ...
# 44441       17036    Men       Footwear       Shoes           Casual Shoes
# 44442        6461    Men       Footwear  Flip Flops             Flip Flops
# 44443       18842    Men        Apparel     Topwear                Tshirts
# 44444       46694  Women  Personal Care   Fragrance  Perfume and Body Mist
# 44445       51623  Women    Accessories     Watches                Watches
#
#       baseColour  season  year   usage  \
# ...

# %%
df_merged.to_csv('/Users/hapresent/Desktop/데이터톤/product_with_pricelabel.csv')

# %%
product = df_merged

# %%
selected_cols = ['product_id', 'price_label']  
df = product[selected_cols]

# %%
df
# Out:
#        product_id   price_label
# 0           15970     low price
# 1           39386  middle price
# 2           59263     low price
# 3           21379     low price
# 4           53759  middle price
# ...           ...           ...
# 44441       17036  middle price
# 44442        6461    high price
# 44443       18842    high price
# 44444       46694     low price
# 44445       51623    high price
#
# [44446 rows x 2 columns]

# %%
query = """
SELECT session_id, product_id, quantity, item_price
FROM view_click_stream_add_to_cart 
"""
df_addcart = pd.read_sql(query, engine)

# %%
df_addcart
# Out:
#                                    session_id product_id quantity item_price
# 0        7d440441-e67a-4d36-b324-80ffd636d166      15315        4     313529
# 1        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       6133        2     249443
# 2        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       6721        1     134504
# 3        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2      57622        1     384716
# 4        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       5490        1     121318
# ...                                       ...        ...      ...        ...
# 1937152  f38416ce-51f2-46b0-a476-776d8fed1cb0       4869        1     282771
# 1937153  c1ce86f6-858b-4009-af5b-f1483a28d020      25127        1     166365
# 1937154  f5c4bbe0-f977-45bb-af23-6ab524df7777      19386        1     208644
# 1937155  ad1063b0-a6e5-40a9-aed6-d1b45741e571      13143        1     284949
# 1937156  64585e37-3fe7-48d7-b79b-ebcb70230eb2      19820        1      88918
#
# [1937157 rows x 4 columns]

# %%
df_addcart['product_id'] = df_addcart['product_id'].astype(str)
df['product_id'] = df['product_id'].astype(str)

df_cart_merged = df_addcart.merge(df, on='product_id', how='left')
# Out:
# /var/folders/f1/hmc3wx1s3l3_ym_59_ssx0gh0000gn/T/ipykernel_90834/961881067.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['product_id'] = df['product_id'].astype(str)

# %%
df_cart_merged
# Out:
#                                    session_id product_id quantity item_price  \
# 0        7d440441-e67a-4d36-b324-80ffd636d166      15315        4     313529
# 1        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       6133        2     249443
# 2        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       6721        1     134504
# 3        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2      57622        1     384716
# 4        f7b5cd60-4f87-4b3c-8bde-c7da8930eec2       5490        1     121318
# ...                                       ...        ...      ...        ...
# 1937152  f38416ce-51f2-46b0-a476-776d8fed1cb0       4869        1     282771
# 1937153  c1ce86f6-858b-4009-af5b-f1483a28d020      25127        1     166365
# 1937154  f5c4bbe0-f977-45bb-af23-6ab524df7777      19386        1     208644
# 1937155  ad1063b0-a6e5-40a9-aed6-d1b45741e571      13143        1     284949
# 1937156  64585e37-3fe7-48d7-b79b-ebcb70230eb2      19820        1      88918
#
#           price_label
# ...

# %% [markdown]
# # 장바구니에 담은 물건들 중 high price 비중 알아보기

# %%
print(df_cart_merged['price_label'].value_counts(normalize = True))
df_cart_merged['price_label'].value_counts()
# Out:
# price_label
# middle price    0.497786
# high price      0.255153
# low price       0.247061
# Name: proportion, dtype: float64
# price_label
# middle price    964290
# high price      494271
# low price       478596
# Name: count, dtype: int64

# %% [markdown]
# ## transaction 테이블 불러오기

# %%
query = """
SELECT *
FROM transactions
"""
df_transaction = pd.read_sql(query, engine)

# %% [markdown]
# ## order_items 테이블 불러오기 ㅡ

# %%
query = """
SELECT *
FROM order_items
"""
df_order_items = pd.read_sql(query, engine)

# %%
df_order_items
# Out:
#                                    booking_id  product_id  quantity  \
# 0        186e2bee-0637-4710-8981-50c2d737bc42       54728         1
# 1        caadb57b-e808-4f94-9e96-8a7d4c9898db       16193         1
# 2        6000fffb-9c1a-4f4a-9296-bc8f6b622b50       53686         4
# 3        f5e530a7-4350-4cd1-a3bc-525b5037bcab       20228         1
# 4        0efc0594-dbbf-4f9a-b0b0-a488cfddf8a2       55220         1
# ...                                       ...         ...       ...
# 1254580  66f02fa4-c62e-497a-8b6e-be239009b50a       30642         2
# 1254581  ccde6b83-ee42-4cce-b2cd-976574886eac       19394         1
# 1254582  5bcd3434-1dc6-44bb-ae63-fd19714cbd6c       13079         4
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15       11312         1
# 1254584  b242e188-5f94-4448-a038-c5865842374b       47433         1
#
#          item_price
# 0            191247
# 1            145526
# 2            135174
# 3            271012
# 4            198753
# ...             ...
# ...

# %%
df_merged_orders = df_order_items.merge(df_transaction, on='booking_id', how='left')

# %%
df_merged_orders
# Out:
#                                    booking_id  product_id  quantity  \
# 0        186e2bee-0637-4710-8981-50c2d737bc42       54728         1
# 1        caadb57b-e808-4f94-9e96-8a7d4c9898db       16193         1
# 2        6000fffb-9c1a-4f4a-9296-bc8f6b622b50       53686         4
# 3        f5e530a7-4350-4cd1-a3bc-525b5037bcab       20228         1
# 4        0efc0594-dbbf-4f9a-b0b0-a488cfddf8a2       55220         1
# ...                                       ...         ...       ...
# 1254580  66f02fa4-c62e-497a-8b6e-be239009b50a       30642         2
# 1254581  ccde6b83-ee42-4cce-b2cd-976574886eac       19394         1
# 1254582  5bcd3434-1dc6-44bb-ae63-fd19714cbd6c       13079         4
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15       11312         1
# 1254584  b242e188-5f94-4448-a038-c5865842374b       47433         1
#
#          item_price          created_at  customer_id  \
# 0            191247 2018-07-29 15:22:01         5868
# ...

# %%
df_success_orders = df_merged_orders[df_merged_orders['payment_status'] == 'Success']

# %%
df_success_orders
# Out:
#                                    booking_id  product_id  quantity  \
# 0        186e2bee-0637-4710-8981-50c2d737bc42       54728         1
# 1        caadb57b-e808-4f94-9e96-8a7d4c9898db       16193         1
# 2        6000fffb-9c1a-4f4a-9296-bc8f6b622b50       53686         4
# 3        f5e530a7-4350-4cd1-a3bc-525b5037bcab       20228         1
# 4        0efc0594-dbbf-4f9a-b0b0-a488cfddf8a2       55220         1
# ...                                       ...         ...       ...
# 1254579  7fdc05d1-234b-4889-a343-587ffc0635d5       42915         1
# 1254581  ccde6b83-ee42-4cce-b2cd-976574886eac       19394         1
# 1254582  5bcd3434-1dc6-44bb-ae63-fd19714cbd6c       13079         4
# 1254583  af7f291a-b01b-4bfd-89a9-237b16368b15       11312         1
# 1254584  b242e188-5f94-4448-a038-c5865842374b       47433         1
#
#          item_price          created_at  customer_id  \
# 0            191247 2018-07-29 15:22:01         5868
# ...

# %%
df_orders_labeled = df_orders.merge(df_price, on='product_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df_orders_labeled = df_orders.merge(df_price, on='product_id', how='left')
#
# NameError: name 'df_orders' is not defined
